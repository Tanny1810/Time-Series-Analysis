# %% [markdown]
# ## Import Libraries

# %%
import math
import datetime

import numpy as np

import pandas as pd
from pandas.plotting import autocorrelation_plot

from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import xgboost as xgb

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Load

# %%
# Loading Data
df = pd.read_csv("Natural Gas Futures Historical Data_2012-2022.csv", header = 0, parse_dates=[0])
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
df
# Out:
#            Date  Price   Open   High    Low     Vol. Change %
# 0    2022-06-15  574.0  571.3  576.1  565.0   17.10K    0.17%
# 1    2022-06-14  573.0  678.7  693.3  551.6   90.20K  -14.71%
# 2    2022-06-13  671.8  688.3  697.2  656.6  107.54K   -2.75%
# 3    2022-06-10  690.8  697.8  712.8  674.2   78.64K   -0.07%
# 4    2022-06-09  691.3  658.5  698.2  625.3  149.22K    1.01%
# ...         ...    ...    ...    ...    ...      ...      ...
# 2686 2012-05-21  146.8  149.5  150.4  145.2   81.35K   -2.59%
# 2687 2012-05-19  150.7  147.5  151.5  147.5    6.21K    2.45%
# 2688 2012-05-18  147.1  139.8  148.1  139.8  108.03K    6.36%
# 2689 2012-05-17  138.3  142.8  146.1  136.7  118.45K   -2.61%
# 2690 2012-05-16  142.0  135.0  142.5  135.0  103.93K    5.42%
#
# [2691 rows x 7 columns]

# %%
plt.figure(figsize=(15, 10), dpi=100)
plt.plot(df['Date'], df['Price'], label='Natural Gas stock')
plt.xlabel('Date')
plt.ylabel('INR')
plt.xticks(rotation = 60)
plt.title('Natural Gas stock price')
plt.legend()
plt.show()

# %% [markdown]
# ## Technical Indicators

# %%
def tech_indicators(df):
    # creating moving average for 7 days and 21 days
    df['ma7'] = df['Price'].rolling(window=7, min_periods=1).mean()
    df['ma21'] = df['Price'].rolling(window=21, min_periods=1).mean()

    # create MACD(Moving average convergence divergence)
    # ewma(Exponentially-weighted moving average)
    df['26ema'] = df['Price'].ewm(span= 26, adjust=False).mean()
    df['12ema'] = df['Price'].ewm(span= 12, adjust=False).mean()
    df['MACD'] = (df['12ema']-df['26ema'])
    
    # Create Bollinger Bands
    ## size of moving window is 20
    df['20sd'] = df['Price'].rolling(window=20, min_periods=1).std()
    df['upper_band'] = df['ma21'] + (df['20sd']*2)
    df['lower_band'] = df['ma21'] - (df['20sd']*2)
    
    # Exponential moving average
    ## ewm exponentially weighted
    df['ema'] = df['Price'].ewm(com=0.5).mean()
    
    # momentum
    df['momentum'] = df['Price'] - 1
    
    df['log_momentum'] = np.log(df['momentum'])
    
    return df

# %%
df_tech_indi = tech_indicators(df[['Price']])
df_tech_indi.head(22)
# Out:
#     Price         ma7        ma21       26ema       12ema       MACD  \
# 0   574.0  574.000000  574.000000  574.000000  574.000000   0.000000
# 1   573.0  573.500000  573.500000  573.925926  573.846154  -0.079772
# 2   671.8  606.266667  606.266667  581.175857  588.915976   7.740119
# 3   690.8  627.400000  627.400000  589.296164  604.590442  15.294277
# 4   691.3  640.180000  640.180000  596.852004  617.930374  21.078370
# 5   684.4  647.550000  647.550000  603.337041  628.156470  24.819429
    plt.plot(dataset['upper_band'],label='Upper Band', color='c')
    plt.plot(dataset['lower_band'],label='Lower Band', color='c')
    plt.fill_between(x_, dataset['lower_band'], dataset['upper_band'], alpha=0.35)
    plt.title('Technical indicators for Natural Gas - last {} days.'.format(last_days))
    plt.ylabel('INR')
    plt.legend()

    # Plot second subplot
    plt.subplot(2, 1, 2)
    plt.title('MACD')
    plt.plot(dataset['MACD'],label='MACD', linestyle='-.')
    plt.hlines(15, xmacd_, shape_0, colors='g', linestyles='--')
    plt.hlines(-15, xmacd_, shape_0, colors='g', linestyles='--')
    plt.plot(dataset['log_momentum'],label='Momentum', color='b',linestyle='-')

    plt.legend()
    plt.show()

# %%
plot_tech_indicators(df_tech_indi, 400)

# %% [markdown]
# ## Fourier Transform

# %%
df_FT = df[['Date', 'Price']]
df_FT
# Out:
#            Date  Price
# 0    2022-06-15  574.0
# 1    2022-06-14  573.0
# 2    2022-06-13  671.8
# 3    2022-06-10  690.8
# 4    2022-06-09  691.3
# ...         ...    ...
# 2686 2012-05-21  146.8
# 2687 2012-05-19  150.7
# 2688 2012-05-18  147.1
# 2689 2012-05-17  138.3
# 2690 2012-05-16  142.0
#
# [2691 rows x 2 columns]

# %%
close_fft = np.fft.fft(np.asarray(df_FT['Price'].tolist()))
fft_df = pd.DataFrame({'fft':close_fft})
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

# %%
fft_df
# Out:
#                              fft       absolute     angle
# 0      575584000000.8+0.0000000j  575584.800000  0.000000
# 1     54947.818846+11236.488728j   56084.948738  0.201713
# 2      31014.968670+7869.684847j   31997.815881  0.248494
# 3     17869.388668-58434.764838j   61105.947280 -1.274026
# 4     26582.441674-55025.913013j   61110.369891 -1.120768
# ...                          ...            ...       ...
# 2686   4002.344706+14115.405389j   14671.858520  1.294504
# 2687  26582.441674+55025.913013j   61110.369891  1.120768
# 2688  17869.388668+58434.764838j   61105.947280  1.274026
# 2689   31014.968670-7869.684847j   31997.815881 -0.248494
# 2690  54947.818846-11236.488728j   56084.948738 -0.201713
#
# [2691 rows x 3 columns]

# %%
plt.figure(figsize=(14, 7), dpi=100)
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3, 6, 9, 100]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
plt.plot(df_FT['Price'],  label='Real')
plt.xlabel('Days')
plt.ylabel('INR')
plt.title('Natural Gas (close) stock prices & Fourier transforms')
plt.legend()
plt.show()

# %% [markdown]
# ## ARIMA (Auto Regressive Integrated Moving Average)

# %%
series = df_FT['Price']
model = ARIMA(series, order = (5, 1, 0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 2691
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               -9396.997
# Date:                Fri, 17 Jun 2022   AIC                          18805.994
# Time:                        13:46:55   BIC                          18841.378
# Sample:                             0   HQIC                         18818.792
#                                - 2691
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0183      0.008      2.178      0.029       0.002       0.035
# ar.L2         -0.0563      0.010     -5.804      0.000      -0.075      -0.037
# ar.L3          0.0099      0.009      1.114      0.265      -0.008       0.027
# ar.L4         -0.0601      0.008     -7.388      0.000      -0.076      -0.044
# ar.L5         -0.0675      0.010     -6.729      0.000      -0.087      -0.048
# sigma2        63.3564      0.557    113.788      0.000      62.265      64.448
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):             39232.30
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                             0.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
autocorrelation_plot(series)
plt.figure()
plt.show()

# %%
X = series.values
size = int(len(X) * 0.75)
train, test = X[0:size], X[size:len(X)]
# train, test = train_test_split(X, test_size=0.3)
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast() 
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)

# %%
mse = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % mse)
# Out:
# Test MSE: 30.146

# %%
result = model_fit.get_forecast()
forecast = result.predicted_mean
intervals = [0.2, 0.1, 0.05, 0.01]
for a in intervals:
    ci = result.conf_int(alpha=a)
    print('%.1f%% Confidence Interval: %.3f between %.3f and %.3f' % ((1-a)*100, forecast, ci[0,0], ci[0,1]))
# Out:
# 80.0% Confidence Interval: 138.825 between 128.622 and 149.027
# 90.0% Confidence Interval: 138.825 between 125.730 and 151.919
# 95.0% Confidence Interval: 138.825 between 123.222 and 154.428
# 99.0% Confidence Interval: 138.825 between 118.319 and 159.331

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(test, label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('INR')
plt.title('ARIMA model on Natural Gas stock')
plt.legend()
plt.show()

# %% [markdown]
# ## Feature Importance with XGBoost

# %%
def feature_imp(df):
    data = df.copy()
#     data = data.drop(['Change %', 'Vol.', 'fft'], axis=1)
#     data = data.drop(['log_momentum', 'ema'], axis=1)
    y = data['Price']
    X = data.iloc[:,1:]
    
    X_train, X_test, Y_train, Y_test = train_test_split(X,y, test_size=0.25, random_state=5)

    return (X_train, Y_train), (X_test, Y_test)

# %%
merge_df = pd.merge(df_tech_indi, fft_df, left_index=True, right_index=True, how='inner')
merge_df
# Out:
#       Price         ma7        ma21       26ema       12ema       MACD  \
# 0     574.0  574.000000  574.000000  574.000000  574.000000   0.000000
# 1     573.0  573.500000  573.500000  573.925926  573.846154  -0.079772
# 2     671.8  606.266667  606.266667  581.175857  588.915976   7.740119
# 3     690.8  627.400000  627.400000  589.296164  604.590442  15.294277
# 4     691.3  640.180000  640.180000  596.852004  617.930374  21.078370
# ...     ...         ...         ...         ...         ...        ...
# 2686  146.8  147.014286  136.809524  142.665862  144.137850   1.471988
# 2687  150.7  148.214286  138.119048  143.260984  145.147412   1.886428
# 2688  147.1  148.471429  139.119048  143.545355  145.447810   1.902455
# 2689  138.3  147.957143  139.800000  143.156810  144.348147   1.191337
# 2690  142.0  147.000000  140.452381  143.071121  143.986894   0.915773
#
#            20sd  upper_band  lower_band         ema  momentum  log_momentum  \
# 0           NaN         NaN         NaN  574.000000     573.0      6.350886
# 1      0.707107  574.914214  572.085786  573.250000     572.0      6.349139
# 2     56.755734  719.778135  492.755199  641.476923     670.8      6.508471
# 3     62.721182  752.842364  501.957636  674.770000     689.8      6.536402
# 4     61.376722  762.933444  517.426556  685.835537     690.3      6.537126
# ...         ...         ...         ...         ...       ...           ...
# 2686   9.060086  154.929696  118.689352  148.092530     145.8      4.982236
# 2687   9.102145  156.323339  119.914757  149.830843     149.7      5.008633
# 2688   8.587008  156.293064  121.945031  148.010281     146.1      4.984291
# 2689   8.157972  156.115943  123.484057  141.536760     137.3      4.922168
# 2690   7.614294  155.680969  125.223793  141.845587     141.0      4.948760
#
#                              fft       absolute     angle
# 0      575584000000.8+0.0000000j  575584.800000  0.000000
# 1     54947.818846+11236.488728j   56084.948738  0.201713
# 2      31014.968670+7869.684847j   31997.815881  0.248494
# 3     17869.388668-58434.764838j   61105.947280 -1.274026
# 4     26582.441674-55025.913013j   61110.369891 -1.120768
# ...                          ...            ...       ...
# 2686   4002.344706+14115.405389j   14671.858520  1.294504
# 2687  26582.441674+55025.913013j   61110.369891  1.120768
# 2688  17869.388668+58434.764838j   61105.947280  1.274026
# 2689   31014.968670-7869.684847j   31997.815881 -0.248494
# 2690  54947.818846-11236.488728j   56084.948738 -0.201713
#
# [2691 rows x 15 columns]

# %%
(X_train, Y_train), (X_test, Y_test) = feature_imp(df_tech_indi)

# %%
xgb_reg = xgb.XGBRegressor(gamma=0.0, n_estimators = 200, base_score = 0.5, colsample_bytree=1, learning_rate = 0.05)
xgb_reg
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=1,
#              enable_categorical=False, gamma=0.0, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)

# %%
xgb_model = xgb_reg.fit(X_train, Y_train, eval_metric="rmse", eval_set = [(X_train, Y_train),(X_test, Y_test)])
# Out:
# [0]	validation_0-rmse:214.33011	validation_1-rmse:221.82254
# [1]	validation_0-rmse:203.74205	validation_1-rmse:211.05823
# [2]	validation_0-rmse:193.67940	validation_1-rmse:200.80420
# [3]	validation_0-rmse:184.11571	validation_1-rmse:191.00172
# [4]	validation_0-rmse:175.02748	validation_1-rmse:181.72665
# [5]	validation_0-rmse:166.38493	validation_1-rmse:172.88408
# [6]	validation_0-rmse:158.17601	validation_1-rmse:164.50806
# [7]	validation_0-rmse:150.37314	validation_1-rmse:156.49869
# [8]	validation_0-rmse:142.95694	validation_1-rmse:148.87605
# [9]	validation_0-rmse:135.90326	validation_1-rmse:141.63353
# [10]	validation_0-rmse:129.20335	validation_1-rmse:134.72342
# [11]	validation_0-rmse:122.83300	validation_1-rmse:128.19438
# [12]	validation_0-rmse:116.77467	validation_1-rmse:121.98393
# [13]	validation_0-rmse:111.01733	validation_1-rmse:116.06570
# [14]	validation_0-rmse:105.54527	validation_1-rmse:110.43563
# [15]	validation_0-rmse:100.34399	validation_1-rmse:105.10274
# [16]	validation_0-rmse:95.39613	validation_1-rmse:99.99877
# [17]	validation_0-rmse:90.69524	validation_1-rmse:95.16071
# [18]	validation_0-rmse:86.22899	validation_1-rmse:90.57097
# [19]	validation_0-rmse:81.98112	validation_1-rmse:86.19721
# [20]	validation_0-rmse:77.94183	validation_1-rmse:82.02620
# [114]	validation_0-rmse:0.84334	validation_1-rmse:2.81919
# [115]	validation_0-rmse:0.81092	validation_1-rmse:2.78917
# [116]	validation_0-rmse:0.78023	validation_1-rmse:2.76619
# [117]	validation_0-rmse:0.75105	validation_1-rmse:2.74349
# [118]	validation_0-rmse:0.72335	validation_1-rmse:2.72288
# [119]	validation_0-rmse:0.69702	validation_1-rmse:2.70209
# [120]	validation_0-rmse:0.67197	validation_1-rmse:2.68275
# [121]	validation_0-rmse:0.64823	validation_1-rmse:2.66422
# [122]	validation_0-rmse:0.62560	validation_1-rmse:2.64634
# [123]	validation_0-rmse:0.60403	validation_1-rmse:2.62926
# [124]	validation_0-rmse:0.58358	validation_1-rmse:2.60960
# [125]	validation_0-rmse:0.56428	validation_1-rmse:2.59105
# [126]	validation_0-rmse:0.54589	validation_1-rmse:2.57665
# [127]	validation_0-rmse:0.52834	validation_1-rmse:2.55741
# [128]	validation_0-rmse:0.51175	validation_1-rmse:2.53907
# [129]	validation_0-rmse:0.49597	validation_1-rmse:2.52152
# [130]	validation_0-rmse:0.48096	validation_1-rmse:2.50450
# [131]	validation_0-rmse:0.46669	validation_1-rmse:2.48864
# [132]	validation_0-rmse:0.45315	validation_1-rmse:2.47320
# [133]	validation_0-rmse:0.44022	validation_1-rmse:2.45817
# [134]	validation_0-rmse:0.42804	validation_1-rmse:2.44473
# [135]	validation_0-rmse:0.41631	validation_1-rmse:2.43172
# [136]	validation_0-rmse:0.40523	validation_1-rmse:2.41814
# [137]	validation_0-rmse:0.39444	validation_1-rmse:2.40606
# [138]	validation_0-rmse:0.38432	validation_1-rmse:2.39409
# [139]	validation_0-rmse:0.37481	validation_1-rmse:2.38181
# [140]	validation_0-rmse:0.36567	validation_1-rmse:2.37078
# [141]	validation_0-rmse:0.35700	validation_1-rmse:2.36010
# [142]	validation_0-rmse:0.34880	validation_1-rmse:2.35001
# [143]	validation_0-rmse:0.34092	validation_1-rmse:2.34033
# [144]	validation_0-rmse:0.33353	validation_1-rmse:2.33009
# [145]	validation_0-rmse:0.32648	validation_1-rmse:2.32117
# [146]	validation_0-rmse:0.31973	validation_1-rmse:2.31241
# [147]	validation_0-rmse:0.31336	validation_1-rmse:2.30366
# [148]	validation_0-rmse:0.30725	validation_1-rmse:2.29525
# [149]	validation_0-rmse:0.30135	validation_1-rmse:2.28741
# [150]	validation_0-rmse:0.29568	validation_1-rmse:2.27993
# [151]	validation_0-rmse:0.29035	validation_1-rmse:2.27274
# [152]	validation_0-rmse:0.28534	validation_1-rmse:2.26581
# [153]	validation_0-rmse:0.28056	validation_1-rmse:2.25924
# [154]	validation_0-rmse:0.27585	validation_1-rmse:2.25262
# [155]	validation_0-rmse:0.27145	validation_1-rmse:2.24641
# [156]	validation_0-rmse:0.26734	validation_1-rmse:2.24018
# [157]	validation_0-rmse:0.26349	validation_1-rmse:2.23449
# [158]	validation_0-rmse:0.25972	validation_1-rmse:2.22889
# [159]	validation_0-rmse:0.25615	validation_1-rmse:2.22321
# [160]	validation_0-rmse:0.25278	validation_1-rmse:2.21784
# [161]	validation_0-rmse:0.24937	validation_1-rmse:2.21280
# [162]	validation_0-rmse:0.24606	validation_1-rmse:2.20774
# [163]	validation_0-rmse:0.24313	validation_1-rmse:2.20302
# [164]	validation_0-rmse:0.24035	validation_1-rmse:2.19819
# [165]	validation_0-rmse:0.23765	validation_1-rmse:2.19369
# [166]	validation_0-rmse:0.23500	validation_1-rmse:2.18950
# [167]	validation_0-rmse:0.23247	validation_1-rmse:2.18540
# [168]	validation_0-rmse:0.23020	validation_1-rmse:2.18147
# [169]	validation_0-rmse:0.22786	validation_1-rmse:2.17776
# [170]	validation_0-rmse:0.22563	validation_1-rmse:2.17408
# [171]	validation_0-rmse:0.22362	validation_1-rmse:2.17056
# [172]	validation_0-rmse:0.22171	validation_1-rmse:2.16720
# [173]	validation_0-rmse:0.21992	validation_1-rmse:2.16395
# [174]	validation_0-rmse:0.21819	validation_1-rmse:2.16058
# [175]	validation_0-rmse:0.21648	validation_1-rmse:2.15746
# [176]	validation_0-rmse:0.21476	validation_1-rmse:2.15443
# [177]	validation_0-rmse:0.21312	validation_1-rmse:2.15155
# [178]	validation_0-rmse:0.21153	validation_1-rmse:2.14855
# [179]	validation_0-rmse:0.21002	validation_1-rmse:2.14590
# [180]	validation_0-rmse:0.20855	validation_1-rmse:2.14316
# [181]	validation_0-rmse:0.20707	validation_1-rmse:2.14054
# [182]	validation_0-rmse:0.20573	validation_1-rmse:2.13773
# [183]	validation_0-rmse:0.20465	validation_1-rmse:2.13550
# [184]	validation_0-rmse:0.20342	validation_1-rmse:2.13313
# [185]	validation_0-rmse:0.20233	validation_1-rmse:2.13091
# [186]	validation_0-rmse:0.20131	validation_1-rmse:2.12880
# [187]	validation_0-rmse:0.20017	validation_1-rmse:2.12672
# [188]	validation_0-rmse:0.19916	validation_1-rmse:2.12462
# [189]	validation_0-rmse:0.19835	validation_1-rmse:2.12279
# [190]	validation_0-rmse:0.19730	validation_1-rmse:2.12083
# [191]	validation_0-rmse:0.19647	validation_1-rmse:2.11857
# [192]	validation_0-rmse:0.19550	validation_1-rmse:2.11674
# [193]	validation_0-rmse:0.19483	validation_1-rmse:2.11508
# [194]	validation_0-rmse:0.19413	validation_1-rmse:2.11332
# [195]	validation_0-rmse:0.19329	validation_1-rmse:2.11169
# [196]	validation_0-rmse:0.19246	validation_1-rmse:2.11005
# [197]	validation_0-rmse:0.19171	validation_1-rmse:2.10853
# [198]	validation_0-rmse:0.19107	validation_1-rmse:2.10696
# [199]	validation_0-rmse:0.19044	validation_1-rmse:2.10570

# %%
xgb_result = xgb_reg.evals_result()

# %%
res = xgb_reg.predict(X_test)

# %%
training_rounds = range(0,len(xgb_result['validation_0']['rmse']))

# %%
plt.scatter(x=training_rounds,y=xgb_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=xgb_result['validation_1']['rmse'],label='Validation Error')
plt.xlabel('Iterations')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=100)
x = list(range(0, len(Y_test), 1))
plt.plot(x,res, label='Predicted')
plt.plot(x,Y_test, color='red', label='Real')
plt.xlabel('Days')
plt.ylabel('INR')

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
plt.xticks(rotation='vertical')
plt.bar([i for i in range(len(xgb_model.feature_importances_))], xgb_model.feature_importances_.tolist(), tick_label=X_test.columns)
plt.title('Feature importance of the technical indicators.')
plt.show()

# %% [markdown]
# ### Excluding Momentum, exponential moving average (ema) and log momentum

# %%
def feature_imp(df):
    data = df.copy()
#     data = data.drop(['Change %', 'Vol.', 'fft'], axis=1)
    data = data.drop(['momentum','log_momentum', 'ema'], axis=1)
    y = data['Price']
    X = data.iloc[:,1:]
    
    X_train, X_test, Y_train, Y_test = train_test_split(X,y, test_size=0.25, random_state=5)

    return (X_train, Y_train), (X_test, Y_test)

# %%
(X_train, Y_train), (X_test, Y_test) = feature_imp(df_tech_indi)

# %%
xgb_reg = xgb.XGBRegressor(gamma=0.0, n_estimators = 200, base_score = 0.5, colsample_bytree=1, learning_rate = 0.05)
xgb_reg
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=1,
#              enable_categorical=False, gamma=0.0, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)

# %%
xgb_model = xgb_reg.fit(X_train, Y_train, eval_metric="rmse", eval_set = [(X_train, Y_train),(X_test, Y_test)])
# Out:
# [0]	validation_0-rmse:214.34286	validation_1-rmse:221.86053
# [1]	validation_0-rmse:203.76900	validation_1-rmse:211.10756
# [2]	validation_0-rmse:193.72015	validation_1-rmse:200.89996
# [3]	validation_0-rmse:184.16763	validation_1-rmse:191.13226
# [4]	validation_0-rmse:175.09030	validation_1-rmse:181.84930
# [5]	validation_0-rmse:166.46693	validation_1-rmse:173.09288
# [6]	validation_0-rmse:158.26987	validation_1-rmse:164.72246
# [7]	validation_0-rmse:150.48238	validation_1-rmse:156.78337
# [8]	validation_0-rmse:143.08424	validation_1-rmse:149.17470
# [9]	validation_0-rmse:136.05159	validation_1-rmse:141.93588
# [10]	validation_0-rmse:129.36440	validation_1-rmse:135.09325
# [11]	validation_0-rmse:123.01067	validation_1-rmse:128.61197
# [12]	validation_0-rmse:116.97805	validation_1-rmse:122.40871
# [13]	validation_0-rmse:111.24046	validation_1-rmse:116.52459
# [14]	validation_0-rmse:105.78832	validation_1-rmse:110.95971
# [15]	validation_0-rmse:100.60919	validation_1-rmse:105.68235
# [16]	validation_0-rmse:95.68536	validation_1-rmse:100.63878
# [17]	validation_0-rmse:91.01081	validation_1-rmse:95.83638
# [18]	validation_0-rmse:86.56496	validation_1-rmse:91.28264
# [19]	validation_0-rmse:82.34161	validation_1-rmse:86.96842
# [20]	validation_0-rmse:78.32846	validation_1-rmse:82.83916
# [21]	validation_0-rmse:74.52065	validation_1-rmse:78.96288
# [22]	validation_0-rmse:70.89925	validation_1-rmse:75.25857
# [23]	validation_0-rmse:67.45784	validation_1-rmse:71.73193
# [24]	validation_0-rmse:64.19172	validation_1-rmse:68.39483
# [25]	validation_0-rmse:61.08759	validation_1-rmse:65.22826
# [26]	validation_0-rmse:58.14090	validation_1-rmse:62.21408
# [27]	validation_0-rmse:55.34205	validation_1-rmse:59.36482
# [28]	validation_0-rmse:52.68327	validation_1-rmse:56.64096
# [29]	validation_0-rmse:50.15997	validation_1-rmse:54.04834
# [30]	validation_0-rmse:47.76562	validation_1-rmse:51.59424
# [31]	validation_0-rmse:45.49169	validation_1-rmse:49.27408
# [32]	validation_0-rmse:43.33134	validation_1-rmse:47.07129
# [33]	validation_0-rmse:41.28108	validation_1-rmse:44.98935
# [34]	validation_0-rmse:39.33543	validation_1-rmse:43.00574
# [35]	validation_0-rmse:37.48642	validation_1-rmse:41.14055
# [36]	validation_0-rmse:35.73107	validation_1-rmse:39.37607
# [37]	validation_0-rmse:34.06305	validation_1-rmse:37.70925
# [38]	validation_0-rmse:32.48037	validation_1-rmse:36.12863
# [39]	validation_0-rmse:30.97579	validation_1-rmse:34.62280
# [40]	validation_0-rmse:29.55123	validation_1-rmse:33.18958
# [41]	validation_0-rmse:28.19815	validation_1-rmse:31.85353
# [42]	validation_0-rmse:26.91444	validation_1-rmse:30.61309
# [43]	validation_0-rmse:25.69614	validation_1-rmse:29.41665
# [44]	validation_0-rmse:24.53857	validation_1-rmse:28.27252
# [45]	validation_0-rmse:23.44021	validation_1-rmse:27.21604
# [46]	validation_0-rmse:22.39996	validation_1-rmse:26.22185
# [47]	validation_0-rmse:21.41300	validation_1-rmse:25.26989
# [48]	validation_0-rmse:20.47502	validation_1-rmse:24.37648
# [49]	validation_0-rmse:19.58528	validation_1-rmse:23.53418
# [50]	validation_0-rmse:18.74290	validation_1-rmse:22.73784
# [51]	validation_0-rmse:17.94642	validation_1-rmse:21.99268
# [52]	validation_0-rmse:17.19072	validation_1-rmse:21.30421
# [53]	validation_0-rmse:16.47391	validation_1-rmse:20.63870
# [54]	validation_0-rmse:15.79563	validation_1-rmse:19.99954
# [55]	validation_0-rmse:15.15376	validation_1-rmse:19.41240
# [56]	validation_0-rmse:14.54591	validation_1-rmse:18.88249
# [57]	validation_0-rmse:13.97195	validation_1-rmse:18.39747
# [58]	validation_0-rmse:13.42864	validation_1-rmse:17.89993
# [59]	validation_0-rmse:12.91358	validation_1-rmse:17.45914
# [60]	validation_0-rmse:12.43109	validation_1-rmse:17.03459
# [61]	validation_0-rmse:11.97393	validation_1-rmse:16.62862
# [62]	validation_0-rmse:11.54092	validation_1-rmse:16.24806
# [63]	validation_0-rmse:11.12748	validation_1-rmse:15.90932
# [64]	validation_0-rmse:10.74020	validation_1-rmse:15.56907
# [65]	validation_0-rmse:10.37533	validation_1-rmse:15.27006
# [66]	validation_0-rmse:10.03385	validation_1-rmse:14.99452
# [67]	validation_0-rmse:9.71164	validation_1-rmse:14.75314
# [68]	validation_0-rmse:9.40530	validation_1-rmse:14.53189
# [69]	validation_0-rmse:9.12222	validation_1-rmse:14.29542
# [70]	validation_0-rmse:8.85095	validation_1-rmse:14.09777
# [71]	validation_0-rmse:8.59829	validation_1-rmse:13.88413
# [72]	validation_0-rmse:8.35341	validation_1-rmse:13.68143
# [73]	validation_0-rmse:8.12586	validation_1-rmse:13.52124
# [74]	validation_0-rmse:7.91007	validation_1-rmse:13.34118
# [75]	validation_0-rmse:7.70783	validation_1-rmse:13.20251
# [76]	validation_0-rmse:7.51972	validation_1-rmse:13.06079
# [77]	validation_0-rmse:7.34355	validation_1-rmse:12.93191
# [78]	validation_0-rmse:7.17827	validation_1-rmse:12.82758
# [79]	validation_0-rmse:7.03073	validation_1-rmse:12.72846
# [80]	validation_0-rmse:6.88753	validation_1-rmse:12.61999
# [81]	validation_0-rmse:6.75510	validation_1-rmse:12.51300
# [82]	validation_0-rmse:6.61900	validation_1-rmse:12.43187
# [83]	validation_0-rmse:6.49803	validation_1-rmse:12.34075
# [84]	validation_0-rmse:6.37855	validation_1-rmse:12.27248
# [85]	validation_0-rmse:6.26842	validation_1-rmse:12.18654
# [86]	validation_0-rmse:6.16669	validation_1-rmse:12.10725
# [87]	validation_0-rmse:6.07286	validation_1-rmse:12.04973
# [88]	validation_0-rmse:5.98426	validation_1-rmse:11.99681
# [89]	validation_0-rmse:5.90296	validation_1-rmse:11.94826
# [90]	validation_0-rmse:5.82164	validation_1-rmse:11.88701
# [91]	validation_0-rmse:5.74812	validation_1-rmse:11.84785
# [92]	validation_0-rmse:5.67045	validation_1-rmse:11.78752
# [93]	validation_0-rmse:5.60586	validation_1-rmse:11.74626
# [94]	validation_0-rmse:5.54109	validation_1-rmse:11.70740
# [95]	validation_0-rmse:5.47626	validation_1-rmse:11.67254
# [96]	validation_0-rmse:5.41915	validation_1-rmse:11.63818
# [97]	validation_0-rmse:5.35996	validation_1-rmse:11.60046
# [98]	validation_0-rmse:5.30383	validation_1-rmse:11.56502
# [99]	validation_0-rmse:5.25706	validation_1-rmse:11.54460
# [100]	validation_0-rmse:5.21093	validation_1-rmse:11.50286
# [101]	validation_0-rmse:5.16453	validation_1-rmse:11.46750
# [102]	validation_0-rmse:5.12337	validation_1-rmse:11.42778
# [103]	validation_0-rmse:5.08117	validation_1-rmse:11.40832
# [104]	validation_0-rmse:5.04507	validation_1-rmse:11.38584
# [105]	validation_0-rmse:5.01471	validation_1-rmse:11.35471
# [106]	validation_0-rmse:4.98374	validation_1-rmse:11.32474
# [107]	validation_0-rmse:4.95356	validation_1-rmse:11.30786
# [108]	validation_0-rmse:4.91544	validation_1-rmse:11.28952
# [109]	validation_0-rmse:4.88979	validation_1-rmse:11.26456
# [110]	validation_0-rmse:4.85881	validation_1-rmse:11.25320
# [111]	validation_0-rmse:4.83211	validation_1-rmse:11.23541
# [112]	validation_0-rmse:4.80846	validation_1-rmse:11.22261
# [113]	validation_0-rmse:4.78412	validation_1-rmse:11.21229
# [114]	validation_0-rmse:4.75063	validation_1-rmse:11.19695
# [115]	validation_0-rmse:4.71506	validation_1-rmse:11.18791
# [116]	validation_0-rmse:4.69139	validation_1-rmse:11.17459
# [117]	validation_0-rmse:4.65905	validation_1-rmse:11.15822
# [118]	validation_0-rmse:4.63086	validation_1-rmse:11.14410
# [119]	validation_0-rmse:4.61282	validation_1-rmse:11.13001
# [120]	validation_0-rmse:4.58770	validation_1-rmse:11.13087
# [121]	validation_0-rmse:4.57031	validation_1-rmse:11.12344
# [122]	validation_0-rmse:4.55073	validation_1-rmse:11.10814
# [123]	validation_0-rmse:4.53240	validation_1-rmse:11.10397
# [124]	validation_0-rmse:4.51682	validation_1-rmse:11.10004
# [125]	validation_0-rmse:4.50101	validation_1-rmse:11.09177
# [126]	validation_0-rmse:4.48603	validation_1-rmse:11.08467
# [127]	validation_0-rmse:4.47273	validation_1-rmse:11.07627
# [128]	validation_0-rmse:4.46155	validation_1-rmse:11.06833
# [129]	validation_0-rmse:4.44532	validation_1-rmse:11.05970
# [130]	validation_0-rmse:4.42494	validation_1-rmse:11.05100
# [131]	validation_0-rmse:4.40402	validation_1-rmse:11.04434
# [132]	validation_0-rmse:4.39299	validation_1-rmse:11.03543
# [133]	validation_0-rmse:4.37988	validation_1-rmse:11.02636
# [134]	validation_0-rmse:4.36900	validation_1-rmse:11.01418
# [135]	validation_0-rmse:4.34966	validation_1-rmse:11.00813
# [136]	validation_0-rmse:4.34284	validation_1-rmse:11.00268
# [137]	validation_0-rmse:4.33465	validation_1-rmse:10.99547
# [138]	validation_0-rmse:4.31475	validation_1-rmse:10.99019
# [139]	validation_0-rmse:4.30197	validation_1-rmse:10.98455
# [140]	validation_0-rmse:4.29170	validation_1-rmse:10.98303
# [141]	validation_0-rmse:4.27909	validation_1-rmse:10.97944
# [142]	validation_0-rmse:4.26757	validation_1-rmse:10.97523
# [143]	validation_0-rmse:4.25592	validation_1-rmse:10.97031
# [144]	validation_0-rmse:4.24061	validation_1-rmse:10.96389
# [145]	validation_0-rmse:4.22836	validation_1-rmse:10.96046
# [146]	validation_0-rmse:4.21926	validation_1-rmse:10.95969
# [147]	validation_0-rmse:4.21258	validation_1-rmse:10.95668
# [148]	validation_0-rmse:4.19630	validation_1-rmse:10.95040
# [149]	validation_0-rmse:4.18228	validation_1-rmse:10.94861
# [150]	validation_0-rmse:4.16444	validation_1-rmse:10.94558
# [151]	validation_0-rmse:4.15229	validation_1-rmse:10.94224
# [152]	validation_0-rmse:4.14093	validation_1-rmse:10.93547
# [153]	validation_0-rmse:4.13305	validation_1-rmse:10.93475
# [154]	validation_0-rmse:4.12544	validation_1-rmse:10.93537
# [155]	validation_0-rmse:4.10860	validation_1-rmse:10.93102
# [156]	validation_0-rmse:4.09009	validation_1-rmse:10.92752
# [157]	validation_0-rmse:4.08043	validation_1-rmse:10.92351
# [158]	validation_0-rmse:4.07312	validation_1-rmse:10.92552
# [159]	validation_0-rmse:4.06644	validation_1-rmse:10.92594
# [160]	validation_0-rmse:4.05099	validation_1-rmse:10.92271
# [161]	validation_0-rmse:4.04458	validation_1-rmse:10.92394
# [162]	validation_0-rmse:4.02879	validation_1-rmse:10.91903
# [163]	validation_0-rmse:4.01794	validation_1-rmse:10.91703
# [164]	validation_0-rmse:4.01364	validation_1-rmse:10.91515
# [165]	validation_0-rmse:3.99740	validation_1-rmse:10.91225
# [166]	validation_0-rmse:3.98362	validation_1-rmse:10.90707
# [167]	validation_0-rmse:3.97741	validation_1-rmse:10.90759
# [168]	validation_0-rmse:3.96513	validation_1-rmse:10.90465
# [169]	validation_0-rmse:3.95984	validation_1-rmse:10.90474
# [170]	validation_0-rmse:3.94880	validation_1-rmse:10.90298
# [171]	validation_0-rmse:3.93990	validation_1-rmse:10.90244
# [172]	validation_0-rmse:3.92911	validation_1-rmse:10.89969
# [173]	validation_0-rmse:3.92005	validation_1-rmse:10.89791
# [174]	validation_0-rmse:3.91546	validation_1-rmse:10.89750
# [175]	validation_0-rmse:3.89707	validation_1-rmse:10.89389
# [176]	validation_0-rmse:3.89136	validation_1-rmse:10.89376
# [177]	validation_0-rmse:3.88473	validation_1-rmse:10.89185
# [178]	validation_0-rmse:3.87947	validation_1-rmse:10.88754
# [179]	validation_0-rmse:3.87065	validation_1-rmse:10.88638
# [180]	validation_0-rmse:3.85890	validation_1-rmse:10.88447
# [181]	validation_0-rmse:3.85478	validation_1-rmse:10.88337
# [182]	validation_0-rmse:3.84470	validation_1-rmse:10.88171
# [183]	validation_0-rmse:3.83472	validation_1-rmse:10.87971
# [184]	validation_0-rmse:3.81476	validation_1-rmse:10.88027
# [185]	validation_0-rmse:3.80728	validation_1-rmse:10.87954
# [186]	validation_0-rmse:3.79433	validation_1-rmse:10.87532
# [187]	validation_0-rmse:3.78455	validation_1-rmse:10.87660
# [188]	validation_0-rmse:3.77056	validation_1-rmse:10.87467
# [189]	validation_0-rmse:3.75815	validation_1-rmse:10.87145
# [190]	validation_0-rmse:3.74940	validation_1-rmse:10.86973
# [191]	validation_0-rmse:3.74054	validation_1-rmse:10.86674
# [192]	validation_0-rmse:3.72513	validation_1-rmse:10.86321
# [193]	validation_0-rmse:3.70991	validation_1-rmse:10.86280
# [194]	validation_0-rmse:3.69567	validation_1-rmse:10.85905
# [195]	validation_0-rmse:3.69046	validation_1-rmse:10.85760
# [196]	validation_0-rmse:3.68493	validation_1-rmse:10.86128
# [197]	validation_0-rmse:3.67900	validation_1-rmse:10.86108
# [198]	validation_0-rmse:3.67340	validation_1-rmse:10.86094
# [199]	validation_0-rmse:3.66952	validation_1-rmse:10.85847

# %%
xgb_result = xgb_reg.evals_result()

# %%
res = xgb_reg.predict(X_test)

# %%
training_rounds = range(0,len(xgb_result['validation_0']['rmse']))

# %%
plt.scatter(x=training_rounds,y=xgb_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=xgb_result['validation_1']['rmse'],label='Validation Error')
plt.xlabel('Iterations')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=100)
x = list(range(0, len(Y_test), 1))
plt.plot(x,res, label='Predicted')
plt.plot(x,Y_test, color='red', label='Real')
plt.xlabel('Days')
plt.ylabel('INR')

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
plt.xticks(rotation='vertical')
plt.bar([i for i in range(len(xgb_model.feature_importances_))], xgb_model.feature_importances_.tolist(), tick_label=X_test.columns)
plt.title('Feature importance of the technical indicators.')
plt.show()
